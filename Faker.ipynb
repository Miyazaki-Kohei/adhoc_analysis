# %% [markdown]
# <a href="https://colab.research.google.com/github/Miyazaki-Kohei/adhoc_analysis/blob/main/Faker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Faker

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading Faker-26.0.0-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 19.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.10/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Installing collected packages: faker
# Successfully installed faker-26.0.0

# %%
import pandas as pd
from faker import Faker
import random

fake = Faker()

def generate_fake_data(num_entries=10):
    data = []

    for _ in range(num_entries):
        entry = {
            "Name": fake.name(),
            "Address": fake.address(),
            "Email": fake.email(),
            "Phone Number": fake.phone_number(),
            "Date of Birth": fake.date_of_birth(minimum_age=18, maximum_age=65).strftime("%Y-%m-%d"),
            "Random Number": random.randint(1, 100),
            "Job Title": fake.job(),
            "Company": fake.company(),
            "Lorem Ipsum Text": fake.text(),
        }
        data.append(entry)

    return pd.DataFrame(data)

if __name__ == "__main__":
    num_entries = 10  # You can adjust the number of entries you want to generate
    fake_data_df = generate_fake_data(num_entries)



## Dataframe with Fake Data
fake_data_df
# Out:
#                 Name                                            Address  \
# 0      Manuel Nelson       79702 Woods Stream\nNew Jeremyside, MI 67225
# 1  Miss Wendy Wright                   Unit 2965 Box 3645\nDPO AE 68230
# 2      Brittany Reed        67555 Lee Flat\nNorth Kennethstad, NM 41147
# 3        Tamara Rice                          USCGC David\nFPO AE 84391
# 4       Joseph Ramos          899 Rogers Springs\nWest Gerald, SC 22064
# 5      Kevin Montoya  176 Erica Terrace Apt. 349\nClaireburgh, LA 97624
# 6      Michelle Rowe  93990 Ramirez Viaduct Apt. 461\nPhelpsbury, IA...
# 7         Keith Cole          0790 Olson Mews\nSouth Jennifer, NM 23139
# 8       Rodney Hayes                   PSC 9433, Box 8813\nAPO AE 06569
# 9     David Thompson    772 Gilbert Lake Suite 577\nMarkhaven, AL 02375
#
#                        Email            Phone Number Date of Birth  \
# 0   thompsonlori@example.com           (761)541-5126    1984-10-28
# 1       cedwards@example.net  001-320-208-2841x80416    1970-07-20
# 2      robinhall@example.com            470-850-7902    1979-10-20
# 3         xhicks@example.net            387.508.3096    1963-09-14
# 4      cynthia42@example.org              8792007439    1969-12-18
# 5        oscar10@example.org       374-729-2837x3517    1983-04-14
# 6    chrismiller@example.org    +1-857-749-3656x5694    1985-11-08
# 7   weavernicole@example.net   001-937-995-2105x5916    1980-11-10
# 8  tylerhumphrey@example.net      (237)881-3384x9830    1971-05-13
# 9       nathan58@example.org      (823)825-7631x9015    1965-05-28
#
#    Random Number                         Job Title  \
# 0             20                    Data scientist
# 1             98             Nutritional therapist
# 2             64  Higher education careers adviser
# 3             64          Administrator, education
# 4             76  Training and development officer
# 5             97              Electronics engineer
# 6             51         Engineer, technical sales
# 7             13                     Advice worker
# 8             81         Estate manager/land agent
# 9             25               Engineer, petroleum
#
#                         Company  \
# 0                Spencer-Parker
# 1                Brown and Sons
# 2              Johnson and Sons
# 3                   Kaufman Inc
# 4                Moran-Mitchell
# 5        Hall, Jones and Dorsey
# 6                 Watson-Walker
# 7                      Chen PLC
# 8  Kramer, Chambers and Stevens
# 9          Lynn, Stark and Hall
#
#                                     Lorem Ipsum Text
# 0  Newspaper anyone guy glass. School rich standa...
# 1  Huge Democrat large throughout alone popular s...
# 2  Million role hand design computer seem materia...
# 3  Culture through often military with put own. B...
# 4  Administration fight their north dog attorney ...
# 5  May speak leader my home. Along better key so ...
# 6  Throughout she room likely free born. Three po...
# 7  Watch these positive stop stay position.\nCour...
# 8  Write garden time star piece. Point later they...
# 9  Party maintain available go spring old recogni...
